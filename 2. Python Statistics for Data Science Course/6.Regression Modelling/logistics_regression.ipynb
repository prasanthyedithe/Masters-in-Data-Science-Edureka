# %%
import pandas as pd
import statsmodels.formula.api as sm

# %%
df = pd.read_csv('feedback_mtcars.csv')
df

# %%
y = df['Feedback']
x = df[['mpg','hp','cyl']]
y

# %%
y = df['Feedback']
x = df[['mpg','hp', 'cy']]
x

# %%
model = sm.Logit(y, x)
result = model.fit()

# %%
result.summary()
