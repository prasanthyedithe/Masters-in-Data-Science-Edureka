# %%
import statsmodels.api as sm
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mtcars_for_manymerge.csv')
df

# %%
y = df['cyl']
x = df[['mpg','hp']]
x

# %%
y = df['cyl']
x = df[['mpg','hp']]
y
