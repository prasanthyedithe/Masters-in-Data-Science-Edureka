# %% [markdown]
# #### 1. Find the highest rated movie in the “Quest” story type.

# %%
import pandas as pd
df = pd.read_csv('HollywoodMovies.csv')

df_quest = df[df['Story'] == 'Quest']['RottenTomatoes'].max()

highest_rated_movies = df[df["RottenTomatoes"] == df_quest]

print(highest_rated_movies)
# Out:
#                Movie   LeadStudio  RottenTomatoes  AudienceScore  \
# 10       Ratatouille       Disney            97.0           84.0
# 343  The Hurt Locker  Independent            97.0           83.0
# 611       The Artist    Weinstein            97.0           91.0
# 629      The Muppets       Disney            97.0           87.0
# 830          Gravity  Warner Bros            97.0           85.0
#
#               Story      Genre  TheatersOpenWeek  OpeningWeekend  \
# 10   Transformation  Animation            3940.0           47.00
# 343           Quest      Drama               4.0            0.14
# 611             NaN      Drama             662.0            2.37
# 629           Quest     Comedy            3440.0           29.24
# 830             NaN        NaN            3820.0           55.79
#
#      BOAvgOpenWeekend  DomesticGross  ForeignGross  WorldGross  Budget  \
# 10            11935.0        206.450       417.280     623.720   150.0
# 343           36338.0         17.010        32.210      49.220    15.0
# 611            3583.0         44.671        88.761     133.432    16.0
# 629            8500.0         88.630        76.550     165.180    45.0
# 830           14603.0        261.210       427.300     688.510   100.0
#
#      Profitability  OpenProfit  Year
# 10          415.81       31.33  2007
# 343         328.13        0.93  2009
# 611         833.95       14.81  2011
# 629         367.08       64.98  2011
# 830         688.51       55.79  2013

# %% [markdown]
# #### 2. Find the genre in which there has been the greatest number of movie releases

# %%
import pandas as pd
df = pd.read_csv('HollywoodMovies.csv')

df.Genre.value_counts()
# Out:
# Comedy         177
# Action         166
# Drama          109
# Horror          52
# Animation       51
# Thriller        35
# Adventure       30
# Romance         20
# Crime           15
# Biography       14
# Documentary      7
# Fantasy          6
# Mystery          5
# Musical          4
# Name: Genre, dtype: int64

# %% [markdown]
# #### 3. Print the names of the top five movies with the costliest budgets.

# %%
import pandas as pd

df = pd.read_csv('HollywoodMovies.csv')

sorted_df = df.sort_values("Budget", ascending=False)

sorted_df = sorted_df[sorted_df["Budget"] > 0]  # removing nan values

print(sorted_df.head(5))
# Out:
#                                         Movie   LeadStudio  RottenTomatoes  \
# 3    Pirates of the Caribbean: At World's End       Disney            45.0
# 468                                   Tangled       Disney            89.0
# 0                                Spider-Man 3         Sony            61.0
# 778                     The Dark Knight Rises  Warner Bros            88.0
# 241    Harry Potter and the Half-Blood Prince  Warner Bros            83.0
#
#      AudienceScore          Story      Genre  TheatersOpenWeek  \
# 3             74.0         Rescue     Action            4362.0
# 468           88.0           Love  Animation            3603.0
# 0             54.0  Metamorphosis     Action            4252.0
# 778           90.0            NaN        NaN            4404.0
# 241           75.0          Quest  Adventure            4325.0
#
#      OpeningWeekend  BOAvgOpenWeekend  DomesticGross  ForeignGross  \
# 3            114.70           26302.0         309.42        654.00
# 468           48.77           13535.0         200.82        390.97
# 0            151.10           35540.0         336.53        554.34
# 778          160.89           36532.0         448.14        636.30
# 241           77.80           17997.0         302.00        632.00
#
#      WorldGross  Budget  Profitability  OpenProfit  Year
# 3       963.420   300.0         321.14       38.23  2007
# 468     591.794   260.0         227.61       18.76  2010
# 0       890.870   258.0         345.30       58.57  2007
# 778    1084.440   250.0         433.78       64.36  2012
# 241     934.000   250.0         373.60       31.12  2009

# %% [markdown]
# #### 4. Is there any correspondence between the critics’ evaluation of a movie and its acceptance by the public? Find out, by plotting the net profitability of a movie against the ratings it receives on Rotten Tomatoes.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('HollywoodMovies.csv')


plt.scatter(df["RottenTomatoes"], df["AudienceScore"])
plt.show()


# Graph between RottenTomatoes vs Profitability
plt.scatter(df["RottenTomatoes"], df["Profitability"])
plt.show()

# %% [markdown]
# #### 5. Perform Operations on Files

# %%
import pandas as pd

# %% [markdown]
# ##### 5.1: From the raw data below create a data frame
# 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
# 'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
# 'age': [42, 52, 36, 24, 73],
# 'preTestScore': [4, 24, 31, ".", "."],
# 'postTestScore': ["25,000", "94,000", 57, 62, 70]

# %%
df = pd.DataFrame({'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
                   'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
                   'age': [42, 52, 36, 24, 73],
                   'preTestScore': [4, 24, 31, ".", "."],
                   'postTestScore': ["25,000", "94,000", 57, 62, 70]})

# %% [markdown]
# ##### 5.2: Save the dataframe into a csv file as example.csv

# %%
df.to_csv("example.csv")
# Out:
# ********************

# %% [markdown]
# ##### 5.3: Read the example.csv and print the data frame

# %%
df = pd.read_csv("example.csv")
print(df)
# Out:
#    Unnamed: 0 first_name last_name  age preTestScore postTestScore
# 0           0      Jason    Miller   42            4        25,000
# 1           1      Molly  Jacobson   52           24        94,000
# 2           2       Tina         .   36           31            57
# 3           3       Jake    Milner   24            .            62
# 4           4        Amy     Cooze   73            .            70
# ********************

# %% [markdown]
# ##### 5.4: Read the example.csv without column heading

# %%
df_without_header = pd.read_csv("example.csv", header=None)
print(df_without_header)
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina          .   36            31             57
# 4  3.0        Jake     Milner   24             .             62
# 5  4.0         Amy      Cooze   73             .             70
# ********************

# %% [markdown]
# ##### 5.5: Read the example.csv andmake the index columns as 'First Name’ and 'Last Name'

# %%
df_with_index = pd.read_csv("example.csv", index_col=[
                            "first_name", "last_name"])
print(df_with_index)
# Out:
#                       Unnamed: 0  age preTestScore postTestScore
# first_name last_name
# Jason      Miller              0   42            4        25,000
# Molly      Jacobson            1   52           24        94,000
# Tina       .                   2   36           31            57
# Jake       Milner              3   24            .            62
# Amy        Cooze               4   73            .            70

# %% [markdown]
# ##### 5.6: Print the data frame in a Boolean form as True or False. True for Null/ NaN values and false for non-null values

# %%
boolean_df = df.isnull().any()
print(boolean_df)
# Out:
# Unnamed: 0       False
# first_name       False
# last_name        False
# age              False
# preTestScore     False
# postTestScore    False
# dtype: bool

# %% [markdown]
# ##### 5.7: Read the dataframe by skipping first 3 rows and print the data frame

# %%
df_skip_rows = pd.read_csv("example.csv", skiprows=3)
print(df_skip_rows)
# Out:
#    2  Tina       .  36 31  57
# 0  3  Jake  Milner  24  .  62
# 1  4   Amy   Cooze  73  .  70

# %% [markdown]
# ##### 5.8: Load a csv file while interpreting "," in strings around numbers as thousands seperators. Check the raw data 'postTestScore' column has, as thousands separator.

# %% [markdown]
# #### 6. Perform Operations on Files

# %%
import pandas as pd

# %% [markdown]
# ##### 6.1: From the raw data below create a Pandas Series 'Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'
# a) Print all elements in lower case
# b) Print all the elements in upper case
# c) Print the length of all the elements

# %%
pds = pd.Series([ 'Amit', 'Bob', 'Kate', 'A', 'b', np.nan, 'Car', 'dog', 'cat'])
print("a) Print all elements in lower case")
print(pds.str.lower())
print(" Print all the elements in upper case")
print(pds.str.upper())
print("Print the length of all the elements")
print(pds.str.len())
# Out:
# a) Print all elements in lower case
# 0    amit
# 1     bob
# 2    kate
# 3       a
# 4       b
# 5     NaN
# 6     car
# 7     dog
# 8     cat
# dtype: object
#  Print all the elements in upper case
# 0    AMIT
# 1     BOB
# 2    KATE
# 3       A
# 4       B
# 5     NaN
# 6     CAR
# 7     DOG
# 8     CAT
# dtype: object
# Print the length of all the elements
# 0    4.0
# 1    3.0
# 2    4.0
# 3    1.0
# 4    1.0
# 5    NaN
# 6    3.0
# 7    3.0
# 8    3.0
# dtype: float64

# %% [markdown]
# ##### 6.2: From the raw data below create a Pandas Series ' Atul', 'John ', ' jack ', 'Sam'
# a) Print all elements after stripping spaces from the left and right
# b) Print all the elements after removing spaces from the left only
# c) Print all the elements after removing spaces from the right only

# %%
pds1 = pd.Series ([' Atul', 'John ', ' jack ', 'Sam'])

print("a) Print all elements after stripping spaces from the left and right") 
print(pds1.str.strip())
print("b) Print all the elements after removing spaces from the left only")
print(pds1.str.lstrip())
print("c) Print all the elements after removing spaces from the right only")
print(pds1.str.rstrip())
# Out:
# a) Print all elements after stripping spaces from the left and right
# 0    Atul
# 1    John
# 2    jack
# 3     Sam
# dtype: object
# b) Print all the elements after removing spaces from the left only
# 0     Atul
# 1    John
# 2    jack
# 3      Sam
# dtype: object
# c) Print all the elements after removing spaces from the right only
# 0     Atul
# 1     John
# 2     jack
# 3      Sam
# dtype: object

# %% [markdown]
# ##### 6.3: - Create a series from the raw data below 'India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture'
# a) split the individual strings wherever ‘_’ comes and create a list out of it.
# b) Access the individual element of a list
# c) Expand the elements so that all individual elements get splitted by ‘_’ and insted of list returns individual elements

# %%
import numpy as np
pds2 = pd.Series(['India_is_big', 'Population_is_huge', np.nan, 'Has_diverse_culture'])

print("a) split the individual strings wherever ‘_’ comes and create a list out of it. ")

list_splited = [str(ele).split("_") for ele in pds2]
print(list_splited)

print("b) Access the individual element of a list  ")
flatten_list = []
for sublist in list_splited:
    for l in sublist:
        flatten_list.append(l)
        print(l)
print("c) Expand the elements so that all individual elements get splitted by ‘_’ and insted of list returns individual elements ")
print(flatten_list)
# Out:
# a) split the individual strings wherever ‘_’ comes and create a list out of it.
# [['India', 'is', 'big'], ['Population', 'is', 'huge'], ['nan'], ['Has', 'diverse', 'culture']]
# b) Access the individual element of a list
# India
# is
# big
# Population
# is
# huge
# nan
# Has
# diverse
# culture
# c) Expand the elements so that all individual elements get splitted by ‘_’ and insted of list returns individual elements
# ['India', 'is', 'big', 'Population', 'is', 'huge', 'nan', 'Has', 'diverse', 'culture']

# %% [markdown]
# ##### 6.4: Create a series and replace either X or dog with XX-XX
# 'A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat'

# %%
pds4 = pd.Series(['A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat'])
pattern = '|'.join(['X', 'dog'])
pds4.str.replace(pattern,'XX-XX', regex=True)
# Out:
# 0           A
# 1           B
# 2           C
# 3    AabXX-XX
# 4    BacXX-XX
# 5
# 6         NaN
# 7        CABA
# 8       XX-XX
# 9         cat
# dtype: object

# %% [markdown]
# ##### 6.5: Create a series and remove dollar from the numeric values '12', '-$10', '$10,000'

# %%
series_5 = pd.Series(['12', '-$10', '$10,000'])
print(series_5)

series_remove_dollar = [str(ele).replace("$", "") for ele in series_5]
print(series_remove_dollar)
# Out:
# 0         12
# 1       -$10
# 2    $10,000
# dtype: object
# ['12', '-10', '10,000']

# %% [markdown]
# ##### 6.6:- Create a series and reverse all lower case words 'india 1998', 'big country', np.nan

# %%
series_6 = pd.Series(['india 1998', 'big country', np.nan])
print(series_6)

print(series_6[::-1])
# Out:
# 0     india 1998
# 1    big country
# 2            NaN
# dtype: object
# 2            NaN
# 1    big country
# 0     india 1998
# dtype: object

# %% [markdown]
# ##### 6.7: Create pandas series and print true if value is alphanumeric in series or false if value is not alpha numeric in series.
# '1', '2', '1a', '2b', '2003c'

# %%
series_7 = pd.Series(['1', '2', '1a', '2b', '2003c'])
print(series_7)

series_aplha_check = [str(ele).isalnum() for ele in series_7]
print(series_aplha_check)
# Out:
# 0        1
# 1        2
# 2       1a
# 3       2b
# 4    2003c
# dtype: object
# [True, True, True, True, True]

# %% [markdown]
# ##### 6.8: Create pandas series and print true if value is containing ‘A’
# '1', '2', '1a', '2b', 'America', 'VietnAm','vietnam', '2003c'

# %%
series_8 = pd.Series(['1', '2', '1a', '2b', 'America',
                      'VietnAm', 'vietnam', '2003c'])
print(series_8)

series_true_if_contains_A = ["A" in str(ele) for ele in series_8]
print(series_true_if_contains_A)
# Out:
# 0          1
# 1          2
# 2         1a
# 3         2b
# 4    America
# 5    VietnAm
# 6    vietnam
# 7      2003c
# dtype: object
# [False, False, False, False, True, True, False, False]

# %% [markdown]
# ##### 6.9: Create pandas series and print in three columns value 0 or 1 is a or b or c exists in values 'a', 'a|b', np.nan, 'a|c'

# %%
import re
series_9 = pd.Series(['a', 'a|b', np.nan, 'a|c'])
print(series_9)

series_a_b_c_exists = [1 if re.match(
    "[abc]", str(ele)) else 0 for ele in series_9]
print(series_a_b_c_exists)
# Out:
# 0      a
# 1    a|b
# 2    NaN
# 3    a|c
# dtype: object
# [1, 1, 0, 1]

# %% [markdown]
# ##### 6.10: Create pandas dataframe having keys and ltable and rtable as below - 'key': ['One', 'Two'], 'ltable': [1, 2] 'key': ['One', 'Two'], 'rtable': [4, 5] Merge both the tables based of key

# %%
df1 = pd.DataFrame({'key': ['One', 'Two'], 'ltable': [1, 2]})
df2 = pd.DataFrame({'key': ['One', 'Two'], 'rtable': [4, 5]})

print(df1)
print(df2)

df_merge = pd.merge(df1, df2, sort=True)
print(df_merge)
# Out:
#    key  ltable
# 0  One       1
# 1  Two       2
#    key  rtable
# 0  One       4
# 1  Two       5
#    key  ltable  rtable
# 0  One       1       4
# 1  Two       2       5
